# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothsnagsr-svg/pythonworkshop/blob/main/pythonworkshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keyword
print(keyword.kwlist)
print(keyword.softkwlist)

x = 5
y = '5'
z= 5.0
print(x)
print(type(x))
print(type(y))
print(type(z))

#Type casting
x = float(x)
print(x)
print(type(x))

#calcuator

a = int(input("Enter a value  "))
b = int(input("Enter b value  "))
print("************************")
print("addition: ",a+b)
print("subtraction: ",a-b)
print("Multiplication: ",a*b)
print("division: ",a//b)
print("***********************")
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# ['_', 'case', 'match', 'type']
# 5
# <class 'int'>
# <class 'str'>
# <class 'float'>
# 5.0
# <class 'float'>

# %%
s = "123"
for i in s:
  if i.isdigit():
    print(type(int(i)))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
# Day 2
# Arithmetic operators,Precedence Operators, Logical Operators , Membership operators(in,not in)

name = "John paul"
s = input()
print("status = ",s in name)
print("status = ",s not in name)

#Bitwise operators

a = 10
b = 10
print(a&b)
# Out:
# u
# status =  True
# status =  False
# 10

# %%
a = 10
b = 10
print(a&b)
print(a|b)
print(a^b)
print(~a)
print(~b)
# Out:
# 10
# 10
# 0
# -11
# -11

# %%
#Identity Operators - is, is not

a = [1,2,3]
b = [1,2,3]
c = a
d = 1
e =1
print(id(d))
print(id(e))
print(id(a))
print(id(b))
print(a==b)
print(a is b)
print(a is c)
# Out:
# 11645352
# 11645352
# 132116992147904
# 132116992160384
# True
# False
# True

# %%
n = int(input()) # Prompts the user to enter a value and converts the input to an integer, storing it in the variable 'n'.
if(n%2==0): # Checks if the number 'n' is divisible by 2 with no remainder (i.e., if it's an even number).
  print(f"{n} is even") # If 'n' is even, it prints a message indicating that 'n' is even.
else: # If the condition in the 'if' statement is false (i.e., 'n' is not even),
  print(f"{n} is odd") # it executes this block and prints a message indicating that 'n' is odd.

# %%
n = 36
print("odd") if n%2!=0 else print("even")
# Out:
# even

# %%
#nested if statement
a=10
b=20
c=30
if a>b or c>b:
  if a>c:
    print("a is greater")
  else:
    print("b is greater") if(b>c) else print("c is greater")
else:
  print("b is greater")
# Out:
# c is greater

# %% [markdown]
# ### Explanation of the code:
#
# This code snippet uses nested `if-else` statements and a conditional expression to determine which of the three variables (`a`, `b`, or `c`) is the greatest, or rather, to print a statement based on a specific set of comparisons.
#
# 1.  **Initialization:**
#     *   `a = 10`
#     *   `b = 20`
#     *   `c = 30`
#     The variables `a`, `b`, and `c` are assigned integer values.
#
# 2.  **Outer `if` condition (`if a>b or c>b`):**
#     *   This is the first condition checked.
#     *   `a > b` evaluates to `10 > 20`, which is `False`.
#     *   `c > b` evaluates to `30 > 20`, which is `True`.
#     *   The `or` operator means if either `False` or `True` is `True`, the whole condition is `True`. So, `False or True` is `True`.
#     *   Since the condition is `True`, the code block inside this `if` statement is executed.
#
# 3.  **Inner `if` condition (`if a>c`):**
#     *   This condition is `a > c`, which evaluates to `10 > 30`, resulting in `False`.
#     *   Since this condition is `False`, the `else` block associated with this inner `if` statement is executed.
#
# 4.  **Inner `else` block (Conditional Expression):**
#     *   `print("b is greater") if(b>c) else print("c is greater")`
#     *   This is a Python conditional expression (often called a ternary operator). It means: if `b > c` is `True`, print "b is greater"; otherwise (if `b > c` is `False`), print "c is greater".
#     *   Let's evaluate `b > c`: `20 > 30`, which is `False`.
#     *   Therefore, the `else` part of this conditional expression is executed: `print("c is greater")`.
#
# ### Test Cases and Verification:
#
# **Test Case 1 (Current values):**
# *   `a = 10`, `b = 20`, `c = 30`
# *   **Execution Trace:**
#     *   `a > b` (10 > 20) is `False`.
#     *   `c > b` (30 > 20) is `True`.
#     *   `False or True` is `True`. (Enter outer `if` block)
#     *   `a > c` (10 > 30) is `False`. (Enter inner `else` block)
#     *   `b > c` (20 > 30) is `False`.
#     *   Result: `print("c is greater")`
# *   **Expected Output:** `c is greater`
# *   **Actual Output (from your kernel state):** `c is greater`
#
# This matches your provided output, so the code works as expected for these specific values.
#
# **Let's consider other test cases to ensure all paths are covered:**
#
# **Test Case 2: `a` is the greatest**
# *   `a = 40`, `b = 20`, `c = 30`
# *   **Execution Trace:**
#     *   `a > b` (40 > 20) is `True`.
#     *   `c > b` (30 > 20) is `True`.
#     *   `True or True` is `True`. (Enter outer `if` block)
#     *   `a > c` (40 > 30) is `True`. (Enter inner `if` block)
#     *   Result: `print("a is greater")`
# *   **Expected Output:** `a is greater`
#
# **Test Case 3: `b` is the greatest**
# *   `a = 10`, `b = 50`, `c = 30`
# *   **Execution Trace:**
#     *   `a > b` (10 > 50) is `False`.
#     *   `c > b` (30 > 50) is `False`.
#     *   `False or False` is `False`. (Enter outer `else` block)
#     *   Result: `print("b is greater")`
# *   **Expected Output:** `b is greater`
#
# **Test Case 4: `a` is greater than `b`, but `c` is the greatest**
# *   `a = 25`, `b = 20`, `c = 30`
# *   **Execution Trace:**
#     *   `a > b` (25 > 20) is `True`.
#     *   `c > b` (30 > 20) is `True`.
#     *   `True or True` is `True`. (Enter outer `if` block)
#     *   `a > c` (25 > 30) is `False`. (Enter inner `else` block)
#     *   `b > c` (20 > 30) is `False`.
#     *   Result: `print("c is greater")`
# *   **Expected Output:** `c is greater`
#
# ### Optimized Solutions:
#
# The provided code, while functional, uses a somewhat convoluted nested `if/else` structure to determine the largest number. Here are a few more straightforward and readable ways to achieve the same goal:
#
# **1. Using the built-in `max()` function (most Pythonic):**
#
# ```python
# a = 10
# b = 20
# c = 30
#
# largest = max(a, b, c)
# print(f"{largest} is the greatest")
# ```
# This is the simplest and most efficient way to find the maximum value among several numbers in Python.
#
# **2. Using a more structured `if-elif-else` chain:**
#
# ```python
# a = 10
# b = 20
# c = 30
#
# if a >= b and a >= c:
#     print(f"{a} is the greatest")
# elif b >= a and b >= c:
#     print(f"{b} is the greatest")
# else:
#     print(f"{c} is the greatest")
# ```
# This approach directly checks each variable against the others to find the maximum. It's more explicit than the `max()` function but still clearer than the original nested structure.

# %%
#elif statement
marks = int(input())
if(marks<40):
  print("fail")
elif(marks>=41 and marks<60):
  print("c grade")
elif(marks>=60 and marks<80):
  print("B grade")
elif(marks>=80 and marks<=100):
  print("A grade")
# Out:
# 87
# A grade

# %%
units = int(input())
customer = input()
if customer == 'residential':
  print("price = ",units*2)
elif customer == "commercial":
  print("price= ",units*5)
else:
  print("price= ",units*10)
# Out:
# 5
# residential
# price =  10

# %% [markdown]
# **Prompt Engineering**
# process of designing clear and effective instructions so an AI system can produce accurate and useful response.
#
# **Components of a good prompt**
#
# *   clear objective
# *   required programming languages
# *   constraints
# *   Input and output format
#
# **Prompt Techniques**
#
#
# *   Zero shot learning - simple tasks (Fast,Easy and suitable for simple problems)
# *   One shot learning - Example along with task
# *   Few shot learning

# %%
#while loop
n = int(input())
i=1
while(i<=10):
  print(f"{n} * {i} = {n*i}")
  i=i+1
# Out:
# 4
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40

# %%
#continue statement
n = int(input())
i=0
while(i<10):
  i=i+1
  if(i==5):
    continue
  print(f"{n} * {i} = {n*i}")
# Out:
# 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
# 5 * 11 = 55

# %%
books = ["c","Java","JS","c#"]
b = input("Enter book")
i = 0
while(i<len(books)):
  if(books[i]==b):
    print("book found")
    break
  i=i+1
else:
  print("book not found")
# Out:
# Enter bookpython
# book not found

# %%
n = int(input())
i =1
while(i<=n):
  if(i%2==0):
    print(f"{i} is even")
  else:
    print(f"{i} is odd")
  i=i+1
# Out:
# 3
# 1 is odd
# 2 is even
# 3 is odd

# %%
n = int(input())
i =1
while(i<=n):
  print(f"**** {i} table ****")
  j=1
  while(j<=10):
    print(f"{i} * {j} = {i*j}")
    j=j+1
  i=i+1
# Out:
# 5
# **** 1 table ****
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
# 1 * 10 = 10
# **** 2 table ****
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# **** 3 table ****
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
# **** 4 table ****
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40
# **** 5 table ****
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothsnagsr-svg/pythonworkshop/blob/main/pythonworkshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keyword
print(keyword.kwlist)
print(keyword.softkwlist)

x = 5
y = '5'
z= 5.0
print(x)
print(type(x))
print(type(y))
print(type(z))

#Type casting
x = float(x)
print(x)
print(type(x))

#calcuator

a = int(input("Enter a value  "))
b = int(input("Enter b value  "))
print("************************")
print("addition: ",a+b)
print("subtraction: ",a-b)
print("Multiplication: ",a*b)
print("division: ",a//b)
print("***********************")
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# ['_', 'case', 'match', 'type']
# 5
# <class 'int'>
# <class 'str'>
# <class 'float'>
# 5.0
# <class 'float'>
